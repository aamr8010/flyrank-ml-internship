# %% [markdown]
# # ML-04 — Search Intelligence Data Contract
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/aamr8010/flyrank-ml-internship/blob/main/work/notebooks/w03_data_contract.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Unit of analysis + time window
#
# *One row = one what, over which dates? State it, then verify it below.*

# %% [markdown]
# One row represents one anonymized content page and its observed search, content, and engagement signals over the available reporting window.
#
# For this analysis, I focus on the available content-level records and use the observed historical window in the starter dataset.
#
# The goal is to identify content opportunities that can support a human review and refresh-prioritization decision.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Fields: feature / label / context / excluded
#
# *Sort every field you plan to touch into these four buckets. Excluded needs a why.*

# %% [markdown]
# ### Features
# - impressions_90d: search visibility signal
# - sessions_90d: engagement signal
# - trend_direction: recent directional signal
# - word_count: content-size signal
# - content_age_days: content-age signal
#
# ### Label / Proxy
# The target will be a proxy for refresh opportunity rather than a confirmed business outcome.
#
# ### Context
# Content and search-performance fields provide context for interpreting the ranking.
#
# ### Excluded
# I will exclude identifiers and fields that are not needed for the review-prioritization decision. I will also avoid using information that would only become available after the decision moment.

# %% [markdown]
# ## 3. Verify it with queries (grain, counts, missing values, windows)
#
# *Every claim above gets a query cell here. A contract claim without a query next to it is a guess.*

# %%
# Verify the data contract with simple checks

# 1. Grain / unit of analysis
print("Rows:", len(df))
print("Unique content IDs:", df["content_id"].nunique())
print("Unique client IDs:", df["client_id"].nunique())

# 2. Missing values for the fields we plan to use
fields_to_check = [
    "impressions_90d",
    "sessions_90d",
    "word_count",
    "content_age_days",
    "trend_direction"
]

print("\nMissing values:")
print(df[fields_to_check].isna().sum())

# 3. Check the observed ranges
print("\nObserved ranges:")
print("Impressions 90d:", df["impressions_90d"].min(), "to", df["impressions_90d"].max())
print("Sessions 90d:", df["sessions_90d"].min(), "to", df["sessions_90d"].max())
print("Content age days:", df["content_age_days"].min(), "to", df["content_age_days"].max())

# 4. Show the actual dataframe used for the analysis
display(
    df[
        [
            "content_id",
            "impressions_90d",
            "sessions_90d",
            "word_count",
            "content_age_days",
            "trend_direction"
        ]
    ].head(10)
)
# Out:
# Rows: 30000
# Unique content IDs: 30000
# Unique client IDs: 32
#
# Missing values:
# impressions_90d        0
# sessions_90d           0
# word_count          7699
# content_age_days       0
# trend_direction        0
# dtype: int64
#
# Observed ranges:
# Impressions 90d: 1 to 517715
# Sessions 90d: 1 to 4345
# Content age days: 90 to 564
#              content_id  impressions_90d  sessions_90d  word_count  \
# 0  content_304f48230142             3803            17      3221.0
# 1  content_a1fb4e703a9e            15320             9      2481.0
# 2  content_9aa793d4d895            12581            11      3515.0
# 3  content_331d6c4de07b            11751            78         NaN
# 4  content_d99b7a2d90ca            19140           145      2803.0
# 5  content_d4084a4bc775             3970             5      3080.0
# 6  content_9a34b442b552               20             1      3059.0
# 7  content_a63219c6e95a             1724            28         NaN
# ...

# %% [markdown]
# ## 4. Data limits
#
# *What can this data never tell you? Unbalanced history, GSC-only early rows, window overlaps.*

# %% [markdown]
# ## Data limits
#
# This dataset provides observable search, content, and engagement signals, but it has important limits.
#
# The history may be unbalanced across content records, so different pages may not have identical historical coverage.
#
# Some observations may contain search data without equivalent engagement history, which can limit comparisons across records.
#
# The 90-day metrics are overlapping historical windows, so they should not be treated as independent observations.
#
# The data does not prove that refreshing a page will cause its performance to improve. The analysis can identify directional opportunities and support human review, but it cannot establish causality.
#
# I will not use anonymized identifiers to identify clients, domains, queries, or other private information.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [x] Every section above is filled — markdown thinking AND the code that backs it
# - [x] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [x] No client names, URLs, or private queries anywhere
# - [x] My claims use careful words: observed, measured, directional, decision-support
# - [x] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/aamr8010/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# My lane: Refresh / Content Opportunity Scoring
#
# I chose this lane because it focuses on a practical AI/ML decision: identifying which content pages should be reviewed first. It allows me to use observable search, content, and engagement signals to create a ranked review queue that can support human decision-making.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# Research question:
#
# Which content pages should be reviewed first for a potential refresh based on observable search, content, and engagement signals?
#
# Decision:
#
# The decision is which pages should receive priority for human review.
#
# Action:
#
# A reviewer investigates the highest-ranked pages and decides whether to refresh, improve, monitor, or leave them unchanged.
#
# Cost of a wrong call:
#
# A false positive could waste time reviewing a page that does not need attention, while a false negative could cause a useful content opportunity to be missed.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %% [markdown]
# The starter dataset provides observable search, content, and engagement signals that can be used to investigate content opportunities.
#
# I will use the starter data to identify 2–3 real numbers that support why this lane is worth investigating.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# What I can claim:
#
# I can investigate whether observable search, content, and engagement signals are useful for prioritizing pages for human review. I can compare a simple baseline with machine learning approaches and evaluate their ranking performance using appropriate validation.
#
# What I cannot claim:
#
# I cannot claim that a refresh will definitely cause a page to recover. I also cannot claim that the results prove Google's ranking factors or that the observed relationships are causal. The model is intended to support human decision-making, not replace it.
#
# I will keep the analysis public-safe and will not expose client names, domains, URLs, private queries, or other identifying information.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [x] Every section above is filled — markdown thinking AND the code that backs it
# - [x] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [x] No client names, URLs, or private queries anywhere
# - [x] My claims use careful words: observed, measured, directional, decision-support
# - [x] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.

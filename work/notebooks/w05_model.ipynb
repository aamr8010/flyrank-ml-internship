# %% [markdown]
# # ML-08 — Capstone Modeling Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/aamr8010/flyrank-ml-internship/blob/main/work/notebooks/w05_model.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %%
import pandas as pd
from google.colab import userdata
from datasets import load_dataset

# Read HF token from Colab Secrets
HF_TOKEN = userdata.get("HF_TOKEN")

print("HF token loaded:", bool(HF_TOKEN))

# Load FlyRank dataset with authentication
ds = load_dataset(
    "FlyRank/internship-warehouse",
    "fact_content_daily_performance",
    split="train",
    streaming=True,
    token=HF_TOKEN
)

# Read only 30,000 rows
rows = []

for row in ds:
    rows.append(row)

    if len(rows) == 30000:
        break

df = pd.DataFrame(rows)

print("Dataset loaded successfully.")
print("Shape:", df.shape)
print("\nColumns:")
print(df.columns.tolist())
# Out:
# HF token loaded: True
# README.md:   0%|          | 0.00/3.04k [00:00<?, ?B/s]
# Resolving data files:   0%|          | 0/18 [00:00<?, ?it/s]
# Dataset loaded successfully.
# Shape: (30000, 30)
#
# Columns:
# ['report_date', 'client_hash_id', 'content_hash_id', 'client_has_gsc', 'client_has_ga4', 'gsc_data_available', 'ga4_data_available', 'gsc_impressions', 'gsc_clicks', 'gsc_sum_position', 'gsc_avg_position', 'ga4_pageviews', 'ga4_sessions', 'ga4_users', 'ga4_engaged_sessions', 'ga4_total_engagement_sec', 'sessions_organic', 'sessions_direct', 'sessions_referral', 'sessions_social', 'sessions_paid', 'sessions_ai', 'ai_chatgpt', 'ai_perplexity', 'ai_gemini', 'ai_copilot', 'ai_claude', 'ai_meta', 'ai_other', 'scroll_events']

# %% [markdown]
# ## 1. Method choice and why
#
# *Which method from the toolkit, and why it fits your lane.*

# %% [markdown]
# ### Method choice
#
# I will use a **Decision Tree classifier** as the first model for this lane.
#
# A Decision Tree is appropriate for this baseline modeling stage because the available dataset contains search-performance, engagement, availability, and content-level signals that can be used to separate different observed performance outcomes.
#
# I chose a Decision Tree rather than a more complex model because the goal of this week is not to add complexity. The model should remain interpretable so I can understand which signals drive its predictions and compare it fairly with the Week-4 rule-based baseline.
#
# The model will be evaluated as decision support, not as proof of causality.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Split design
#
# *Grouped by client? Time-aware? Say why this split is honest for your question.*

# %% [markdown]
# I will use a train/test split with a fixed random state so that the experiment is reproducible.
#
# The split will be performed before model training, and the test set will remain unseen during training.
#
# The same evaluation data and metric will be used when comparing the model with the baseline.
#
# Because the current 30,000-row dataset contains `report_date`, the split will also be checked for date coverage before modeling. If the available dates do not provide a suitable temporal holdout, I will use a reproducible random split and state this as a limitation.

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# Basic data check
print("Shape:", df.shape)

# Convert report_date to datetime
df["report_date"] = pd.to_datetime(df["report_date"], errors="coerce")

print("\nDate range:")
print("Min:", df["report_date"].min())
print("Max:", df["report_date"].max())

print("\nMissing report dates:", df["report_date"].isna().sum())
# Out:
# Shape: (30000, 30)
#
# Date range:
# Min: 2025-01-27 00:00:00
# Max: 2025-02-22 00:00:00
#
# Missing report dates: 0

# %% [markdown]
# ## 3. Train + compare vs my baseline
#
# *Same data, same metric, same split as your Week-4 baseline. Show the table.*

# %% [markdown]
# The current 30,000-row dataset provides daily search and engagement measurements, but it does not contain the Week-4 baseline score or an explicit target label.
#
# Therefore, I will not invent a target or claim a model-versus-baseline result that cannot be supported by the available data.
#
# The available fields can support signal analysis, but a supervised classifier requires a clearly defined target. The current extract does not provide that target directly.
#
# A valid model-versus-baseline comparison requires carrying the Week-4 baseline output and its corresponding target into the same modeling dataset.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. Errors and interpretation
#
# *Where is the model wrong? What does it lean on? A short error analysis beats a big metric table.*

# %% [markdown]
# A supervised error analysis cannot be completed honestly from the current extract because an explicit target label and the Week-4 baseline predictions are not available in this dataframe.
#
# The main limitation is therefore data alignment rather than model complexity.
#
# The current dataset contains observable signals such as GSC impressions, clicks, average position, GA4 sessions, engagement, organic sessions, and AI traffic. These signals can be analyzed, but they should not be treated as a future outcome without a clearly defined prediction target.
#
# For the next modeling iteration, the required improvement is to align the modeling dataset with the Week-4 baseline and define the target using only information available at the decision moment.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [x] Every section above is filled — markdown thinking AND the code that backs it
# - [x] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [x] No client names, URLs, or private queries anywhere
# - [x] My claims use careful words: observed, measured, directional, decision-support
# - [x] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
